# %%
player = 'Thomas'
point = 33
'Last night, ' + player + ' scored ' + str(point) + ' points.'
# Out:
# 'Last night, Thomas scored 33 points.'

# %%
#better way
f'Last night, {player} scored {point} points.'
# Out:
# 'Last night, Thomas scored 33 points.'

# %%
#1
print("I'm going to do %s there." %'something')
# Out:
# I'm going to do something there.

# %%
#2
print("I'm going to do %s there and go %s then." %('something', 'somewhere'))
# Out:
# I'm going to do something there and go somewhere then.

# %%
#3
x = 'something'
y = 'somewhere'
print("I'm going to do %s there and go %s then." %(x, y))
# Out:
# I'm going to do something there and go somewhere then.

# %%
#4
x, y = 'something','somewhere'
print("I'm going to do %s there and go %s then." %(x, y))
# Out:
# I'm going to do something there and go somewhere then.

# %%
print("I was at %r last %r"%('home', 'night'))
# Out:
# I was at 'home' last 'night'

# %%
print("I was at %r last %s"%('home', 'night'))
# Out:
# I was at 'home' last night

# %%
print("I once caught a fish %s."%'this \tbig')
# Out:
# I once caught a fish this 	big.

# %%
print("I once caught a fish %s."%'this\tbig')
# Out:
# I once caught a fish this	big.

# %%
print("I once caught a fish %s."%'this big')
# Out:
# I once caught a fish this big.

# %%
print('I wrote %s programs today.'%365)
# Out:
# I wrote 365 programs today.

# %%
print('I wrote %r programs today.'%365)
# Out:
# I wrote 365 programs today.

# %%
print('I wrote %d programs today.'%36.2489)
# Out:
# I wrote 36 programs today.

# %%
print('Floating point number:%5.2f'%13.144)
# Out:
# Floating point number:13.14

# %%
print('Floating point number:%1.0f'%13.144)
# Out:
# Floating point number:13

# %%
print('Floating point number:%1.5f'%13.144)
# Out:
# Floating point number:13.14400

# %%
print('Floating point number:%10.2f'%13.144)
# Out:
# Floating point number:     13.14

# %%
print('Floating point number:%25.2f'%13.144)
# Out:
# Floating point number:                    13.14

# %%
print('First: %s, Second: %5.2f, Third: %r' %('hi', 3.1254, 'bye'))
# Out:
# First: hi, Second:  3.13, Third: 'bye'

# %%
#5
print('This is a string with an {}'.format('insert'))
# Out:
# This is a string with an insert

# %%
print('The {0} {1} {2}'.format('fox', 'brown', 'quick'))
# Out:
# The fox brown quick

# %%
print('The {2} {1} {0}'.format('fox', 'brown', 'quick'))
# Out:
# The quick brown fox

# %%
print('First object: {a}, Second object: {b}, Third object: {c}'.format(a = 1, b = 'Two', c = 3.152))
# Out:
# First object: 1, Second object: Two, Third object: 3.152

# %%
print('A %s saved is a %r earned.' %('penny', 'penny'))
#vs.
print('A {p} saved is a {p} earned.'.format(p = 'penny'))
# Out:
# A penny saved is a 'penny' earned.
# A penny saved is a penny earned.

# %%
print('{0:8}|{1:9}'.format('fruit', 'quantity'))
print('{0:8}|{1:9}'.format('apple', 3.))
print('{0:8}|{1:9}'.format('oranges', 10))
# Out:
# fruit   |quantity
# apple   |      3.0
# oranges |       10

# %%
print('{0:<8}|{1:^8}|{2:>8}'.format('left', 'center', 'right'))
print('{0:<8}|{1:^8}|{2:>8}'.format(11, 22, 33))
# Out:
# left    | center |   right
# 11      |   22   |      33

# %%
print('{0:=<8}|{1:-^8}|{2:.>8}'.format('left', 'center', 'right'))
print('{0:=<8}|{1:-^8}|{2:.>8}'.format(11, 22, 33))
# Out:
# left====|-center-|...right
# 11======|---22---|......33

# %%
#
print('This is two number: %10.2f' %1326.5482)
print('This is two number:{0:11.2f}'.format(1326.5482))
# Out:
# This is two number:    1326.55
# This is two number:    1326.55

# %%
#6
name = 'Fred'
print(f'He said his name is {name}.') #represent string
print(f'He said his name is {name!r}.') #raw  string
# Out:
# He said his name is Fred.
# He said his name is 'Fred'.

# %%
#f.string value
num = 236.24489
print('number is: {0:10.4f}'.format(num)) #format
print(f'number is: {num: {10}.{7}}') #f.string
print(f'number is: {num: 10.7f}') #format in f.string
# Out:
# number is:   236.2449
# number is:   236.2449
# number is:  236.2448900

# %%
t = template('hey, $name')
s = 'John'
t.substitude(name = s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 t = template('hey, $name')
#       2 s = 'John'
#       3 t.substitude(name = s)
#
# NameError: name 'template' is not defined

# %%
list = ['art', 23, 10, 2.36, ['str', 5]]
type(list)
len(list)
# Out:
# 5

# %%
type(list)
# Out:
# list

# %%
my_list = ['foo', 'bar', 'baz', 'qux', 'quux', 'corge']
my_list[2]
# Out:
# 'baz'

# %%
my_list[1:]
# Out:
# ['bar', 'baz', 'qux', 'quux', 'corge']

# %%
my_list[2:5]
# Out:
# ['baz', 'qux', 'quux']

# %%
my_list[::-1]
# Out:
# ['corge', 'quux', 'qux', 'baz', 'bar', 'foo']

# %%
'qux' in my_list
# Out:
# True

# %%
'quz' in my_list
# Out:
# False

# %%
'quz' not in my_list
# Out:
# True

# %%
my_list[0] = 35
my_list
# Out:
# [35, 'bar', 'baz', 'qux', 'quux', 'corge']

# %%
S = my_list[::-1]
S[2] = 5
S
# Out:
# ['corge', 'quux', 5, 'baz', 'bar', 35]

# %%
print(id(my_list))
print(id(S))
# Out:
# 2395704090304
# 2395700269184

# %%
L1 = [1, 2, 3]
L2 = [3, 2, 1]
L1 is L2
# Out:
# False

# %%
2 in L1
# Out:
# True

# %%
2 in L1 and L2
# Out:
# [3, 2, 1]

# %%
L1 is L2
# Out:
# False

# %%
L = L1 + L2
L
# Out:
# [1, 2, 3, 3, 2, 1]

# %%
L1 + L2
# Out:
# [1, 2, 3, 3, 2, 1]

# %%
L1
# Out:
# [1, 2, 3]

# %%
L2
# Out:
# [3, 2, 1]

# %%
L
# Out:
# [1, 2, 3, 3, 2, 1]

# %%
L1 + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 L1 + 5
#
# TypeError: can only concatenate list (not "int") to list

# %%
L1 += 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 L1 += 5
#
# TypeError: 'int' object is not iterable

# %%
L1 + [5]
# Out:
# [1, 2, 3, 5]

# %%
L1 += [5]

# %%
L1
# Out:
# [1, 2, 3, 5]

# %%
L1 = [1, 3, 5]
L1 += [6]

# %%
L1
# Out:
# [1, 3, 5, 6]

# %%
L2 = [5, 6, 7]
L2 + [9]
L2
# Out:
# [5, 6, 7]

# %%
L2 + [9]
# Out:
# [5, 6, 7, 9]

# %%
L2
# Out:
# [5, 6, 7]

# %%
L2 += [9]

# %%
L2
# Out:
# [5, 6, 7, 9]

# %%
L2 * 2
# Out:
# [5, 6, 7, 9, 5, 6, 7, 9]

# %%
L2
# Out:
# [5, 6, 7, 9]

# %%
L3 = L2 *2

# %%
L2
# Out:
# [5, 6, 7, 9]

# %%
L3
# Out:
# [5, 6, 7, 9, 5, 6, 7, 9]

# %%
List = [1, 2, 3]
List.append(5)
List
# Out:
# [1, 2, 3, 5]

# %%
List.append(6)
List
# Out:
# [1, 2, 3, 5, 6, 6, 6]

# %%
List.append(7, 8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 List.append(7, 8)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
List.append([7, 8])
List
# Out:
# [1, 2, 3, 5, 6, 6, 6, [7, 8]]

# %%
List.extend(7, 8)
List
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 List.extend(7, 8)
#       2 List
#
# TypeError: list.extend() takes exactly one argument (2 given)

# %%
List.extend([9, 10])

# %%
List
# Out:
# [1, 2, 3, 5, 6, 6, 6, [7, 8], 9, 10]

# %%
List.extend([7, 8, 11, 12])
List
# Out:
# [1, 2, 3, 5, 6, 6, 6, [7, 8], 9, 10, 7, 8, 11, 12]

# %%
List.extend([1, 2, [3, 4]])

# %%
List
# Out:
# [1, 2, 3, 5, 6, 6, 6, [7, 8], 9, 10, 7, 8, 11, 12, 1, 2, [3, 4]]

# %%
List.insert(4, [])

# %%
List
# Out:
# [1, 2, 3, 5, [], 6, 6, 6, [7, 8], 9, 10, 7, 8, 11, 12, 1, 2, [3, 4]]

# %%
List += [77]

# %%
List
# Out:
# [1, 2, 3, 5, [], 6, 6, 6, [7, 8], 9, 10, 7, 8, 11, 12, 1, 2, [3, 4], 77]

# %%
List -= [77]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 List -= [77]
#
# TypeError: unsupported operand type(s) for -=: 'list' and 'list'

# %%
List += ['str']
List
# Out:
# [1, 2, 3, 5, [], 6, 6, 6, [7, 8], 9, 10, 7, 8, 11, 12, 1, 2, [3, 4], 77, 'str']

# %%
List += ['string'!r]
List
# Out:
#   Cell In[135], line 1
#     List += ['string'!r]
#                      ^
# SyntaxError: invalid syntax

# %%
List.pop(5)
List
# Out:
# [1, 2, 3, 5, [], 6, 6, [7, 8], 9, 10, 7, 8, 11, 12, 1, 2, [3, 4], 77, 'str']

# %%
List.pop(6)
# Out:
# 6

# %%
List
# Out:
# [1, 2, 3, 5, [], 6, [7, 8], 9, 10, 7, 8, 11, 12, 1, 2, [3, 4], 77, 'str']

# %%
List.pop(4)
# Out:
# []

# %%
List.remove([7, 8])

# %%
List
# Out:
# [1, 2, 3, 5, 6, 9, 10, 7, 8, 11, 12, 1, 2, [3, 4], 77, 'str']

# %%
List.remove(77)
List
# Out:
# [1, 2, 3, 5, 6, 9, 10, 7, 8, 11, 12, 1, 2, [3, 4], 'str']

# %%
List.remove(7, 8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 List.remove(7, 8)
#
# TypeError: list.remove() takes exactly one argument (2 given)

# %%
del List[6]
List
# Out:
# [1, 2, 3, 5, 6, 9, 7, 8, 11, 12, 1, 2, [3, 4], 'str']

# %%
del List[8:10]
List
# Out:
# [1, 2, 3, 5, 6, 9, 7, 8, 1, 2, [3, 4], 'str']

# %%
List[::-1]
# Out:
# ['str', [3, 4], 2, 1, 8, 7, 9, 6, 5, 3, 2, 1]

# %%
List
# Out:
# [1, 2, 3, 5, 6, 9, 7, 8, 1, 2, [3, 4], 'str']

# %%
List.reverse()

# %%
List
# Out:
# ['str', [3, 4], 2, 1, 8, 7, 9, 6, 5, 3, 2, 1]

# %%
List
# Out:
# ['str', [3, 4], 2, 1, 8, 7, 9, 6, 5, 3, 2, 1]

# %%
List.reverse()
List
# Out:
# [1, 2, 3, 5, 6, 9, 7, 8, 1, 2, [3, 4], 'str']

# %%
List.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 List.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
List.remove('str')

# %%
List.remove([3, 4])

# %%
List
# Out:
# [1, 1, 2, 2, 3, 5, 6, 7, 8, 9]

# %%
List.sort()

# %%
List
# Out:
# [1, 1, 2, 2, 3, 5, 6, 7, 8, 9]

# %%
List.reverse()

# %%
List.sort()
List
# Out:
# [1, 1, 2, 2, 3, 5, 6, 7, 8, 9]

# %%
lst = [5, 7, 9, 2, 7, 6, 8, 1, 2]
lst.sort()
lst
# Out:
# [1, 2, 2, 5, 6, 7, 7, 8, 9]

# %%
str = ['banana', 'car', 'apple', 'door', 'fish','ear']
str.sort()
str
# Out:
# ['apple', 'banana', 'car', 'door', 'ear', 'fish']

# %%
lst.sort(reverse = True)

# %%
lst
# Out:
# [9, 8, 7, 7, 6, 5, 2, 2, 1]

# %%
str.sort(reverse = True)
str
# Out:
# ['fish', 'ear', 'door', 'car', 'banana', 'apple']

# %%
listA = lst.sort(reverse = True)
listA
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 listA = lst.sort(reverse = True)
#       2 listA
#
# NameError: name 'lst' is not defined

# %%
listA = ['a', 'b', 'c', 'd']
listB = listA.sort(reverse = True)
print(listB)
# Out:
# None

# %%
listC = [5, 9, 7, 3, 6, 2]
listC.sort()
listC
# Out:
# [2, 3, 5, 6, 7, 9]

# %%
listC
# Out:
# [2, 3, 5, 6, 7, 9]

# %%
listC.sort(reverse=True)

# %%
listC
# Out:
# [9, 7, 6, 5, 3, 2]

# %%
id(listC)
# Out:
# 2786798594176

# %%
id(listC.sort())
# Out:
# 140732311210112

# %%
id(listC.sort(reverse=True))
# Out:
# 140732311210112

# %%
C = listC
print(id(C))
# Out:
# 2786798594176

# %%
CC = listC.copy()
print(id(CC))
# Out:
# 2786798401728

# %%
C is listC
# Out:
# True

# %%
CC is listC
# Out:
# False

# %%
C is listC.sort()
# Out:
# False

# %%
listC.sort() is listC.sort(reverse=True)
# Out:
# True

# %%
CCC = listC.sort().copy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 CCC = listC.sort().copy()
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %%
new_list = ['apple', 'blue', 'red', 'green', 'car', 'fish', 'hat']
new_list.sort()

# %%
new_list
# Out:
# ['apple', 'blue', 'car', 'fish', 'green', 'hat', 'red']

# %%
new_list[1:5]
# Out:
# ['blue', 'car', 'fish', 'green']

# %%
new_list = ['apple', 'blue', 'red', 'green', 'car', 'fish', 'hat']
new_list.sort()
new_list
new_list[1:5]
# Out:
# ['blue', 'car', 'fish', 'green']

# %%
new_list = ['apple', 'blue', 'red', 'green', 'car', 'fish', 'hat']
new_list.sort()
new_list[1:5]
# Out:
# ['blue', 'car', 'fish', 'green']

# %%
new_list
# Out:
# ['apple', 'blue', 'car', 'fish', 'green', 'hat', 'red']

# %%
new_list = ['apple', 'blue', 'red', 'green', 'car', 'fish', 'hat']
new_list.sort()

new_list[1:5] = ['pink', 'bike', 'bird', 'yellow']
new_list
# Out:
# ['apple', 'pink', 'bike', 'bird', 'yellow', 'hat', 'red']

# %%
new_list
# Out:
# ['apple', 'pink', 'bike', 'bird', 'yellow', 'hat', 'red']

# %%
new_list.sort()
new_list[2:5]
# Out:
# ['bird', 'hat', 'pink']

# %%
new_list
# Out:
# ['apple', 'bike', 'bird', 'hat', 'pink', 'red', 'yellow']

# %%
new_list[2:5] = ['cat', 'scarf']

# %%
new_list
# Out:
# ['apple', 'bike', 'cat', 'scarf', 'red', 'yellow']

# %%
new_list[1:4] = ['airplane', 'bicycle', 'mouse', 'dog', 'dress', 'shoe']
new_list
# Out:
# ['apple',
#  'airplane',
#  'bicycle',
#  'mouse',
#  'dog',
#  'dress',
#  'shoe',
#  'red',
#  'yellow']

# %%
new_list[3:3] = { 'and'}
new_list
# Out:
# ['apple',
#  'airplane',
#  'and',
#  'and',
#  'bicycle',
#  'mouse',
#  'dog',
#  'dress',
#  'shoe',
#  'red',
#  'yellow']

# %%
new_list[2:4] = []
new_list
# Out:
# ['apple',
#  'airplane',
#  'bicycle',
#  'mouse',
#  'dog',
#  'dress',
#  'shoe',
#  'red',
#  'yellow']

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]
list3 = [7, 8, 9]
matrix = [list1, list2, list3]
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[1][2]
# Out:
# 6

# %%
matrix[::-1]
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]

# %%
x = ['a', ['bb', ['ccc', 'ddd'], 'ee', 'ff'], 'g', ['hh', 'ii', ['jjj']]]
x[1][1][1]
# Out:
# 'ddd'

# %%
x[1][1][1][2]
# Out:
# 'd'

# %%
x[1][1][1][2].upper()
# Out:
# 'D'

# %%
x1 = ['a', ['bb', ['333', 'ddd'], 'ee', '66'], 'g', ['hh', '99', ['jjj']]]
x1[3][2]
# Out:
# ['jjj']

# %%
x1[3][1]
# Out:
# '99'

# %%
x1[3][1][1]
# Out:
# '9'

# %%
x2 = ['a', ['bb', [333, 'ddd'], 'ee', 66], 'g', ['hh', 99, ['jjj']]]
x2[3][1]
# Out:
# 99

# %%
x2[3][1][1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 x2[3][1][1]
#
# TypeError: 'int' object is not subscriptable

# %%
t = (1, 2, 3, 4, 5)
print(type(t), len(t))
# Out:
# <class 'tuple'> 5

# %%
t = ('str', 95)
print(type(t), len(t))
# Out:
# <class 'tuple'> 2

# %%
t = ('str1', 'str2', 33, 45, 54, 'str6', 77, 'str8', [99, '10'])
print(type(t), len(t))
# Out:
# <class 'tuple'> 9

# %%
t[8][1][0]
# Out:
# '1'

# %%
t
# Out:
# ('str1', 'str2', 33, 45, 54, 'str6', 77, 'str8', [99, '10'])

# %%
t = (11)
print(t)
print(type(t))
# Out:
# 11
# <class 'int'>

# %%
t =(11, )
print(t)
print(type(t))
# Out:
# (11,)
# <class 'tuple'>

# %%
t = ('str1', 'str2', 33, 45, 54, 'str6', 77, 'str8', [99, '10'])
t.index([99, '10'])
# Out:
# 8

# %%
t = ('str1', 'str2', 33, 45, [99, '10'], 54, 'str6', 77, 'str8', [99, '10'])
t.index([99, '10'])
# Out:
# 4

# %%
t.index([99, '10'])
# Out:
# 4

# %%
t.count([99, '10'])
# Out:
# 2

# %%
t[3] = 56
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 t[3] = 56
#
# TypeError: 'tuple' object does not support item assignment

# %%
t[4][0]
# Out:
# 99

# %%
t[4][0] = 5

# %%
t
# Out:
# ('str1', 'str2', 33, 45, [5, '10'], 54, 'str6', 77, 'str8', [99, '10'])

# %%
x = 1, 'two', 3, 'four', 5, 'six'
x
# Out:
# (1, 'two', 3, 'four', 5, 'six')

# %%
x.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 x.sort()
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %%
x1, x2, x3, x4, x5, x6 = x
print(x1, x2, x3, x4, x5, x6)
# Out:
# 1 two 3 four 5 six

# %%
x
# Out:
# (1, 'two', 3, 'four', 5, 'six')

# %%
x1, x2, x3, x4, x5 = x
print(x1, x2, x3, x4, x5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 x1, x2, x3, x4, x5 = x
#       2 print(x1, x2, x3, x4, x5)
#
# ValueError: too many values to unpack (expected 5)

# %%
x1, x2, x3, x4, x5, x6, x7 = x
print(x1, x2, x3, x4, x5, x6, x7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 x1, x2, x3, x4, x5, x6, x7 = x
#       2 print(x1, x2, x3, x4, x5, x6, x7)
#
# ValueError: not enough values to unpack (expected 7, got 6)
