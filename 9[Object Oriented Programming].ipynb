# %%
print(type(1))
print(type(''))
print(type([]))
print(type(()))
print(type({}))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>

# %%
#Create a new object called Sample
class Sample:
    pass

#Instance of Sample
x = Sample()
print(type(x))
# Out:
# <class '__main__.Sample'>

# %%
import math

class Circle:
    def __init__(self, radius):
        self.radius = radius
    def calculate_area(self):
        return round(math.pi * self.radius**2, 2)

# %%
circle_1 = Circle(42)
circle_2 = Circle(7)

# %%
circle_1.radius
# Out:
# 42

# %%
circle_2.radius
# Out:
# 7

# %%
circle_1.calculate_area()
# Out:
# 5541.77

# %%
circle_2.calculate_area()
# Out:
# 153.94

# %%
circle_1.radius = 100

circle_1.radius
# Out:
# 100

# %%
circle_1.calculate_area()
# Out:
# 31415.93

# %%
class Dog:
    def __init__(self, breed):
        self.breed = breed

sam = Dog('Lab')
frank = Dog('Huski')

# %%
sam.breed
# Out:
# 'Lab'

# %%
frank.breed
# Out:
# 'Huski'

# %%
class Dog:
    def __init__(self, breed, name):
        self.breed = breed
        self.name = name

sam = Dog(breed = 'Lab', name = 'sam')
frank = Dog(breed = 'Huski', name = 'frank')

# %%
sam.name
# Out:
# 'sam'

# %%
sam.breed
# Out:
# 'Lab'

# %%
class Dog:
    species = 'mammal'
    def __init__(self, breed, name):
        self.breed = breed
        self.name = name

sam = Dog(breed = 'Lab', name = 'sam')
frank = Dog(breed = 'Huski', name = 'frank')

# %%
sam.species
# Out:
# 'mammal'

# %%
frank.species
# Out:
# 'mammal'

# %%
Dog.species
# Out:
# 'mammal'

# %%
Dog.breed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 Dog.breed
#
# AttributeError: type object 'Dog' has no attribute 'breed'

# %%
class Dog:
    species = 'mammal'
    def __init__(self, breed, name):
        self.breed = breed
        self.name = name
        print(Dog.species)
        print(type(self).species)

sam = Dog(breed = 'Lab', name = 'sam')
frank = Dog(breed = 'Huski', name = 'frank')
# Out:
# mammal
# mammal
# mammal
# mammal

# %%
class Dog:
    species = 'mammal'
    def __init__(self, breed, name):
        self.breed = breed
        self.name = name
        print(type(self).species)
    def bark(self):
        print('wooof!')

sam = Dog(breed = 'Lab', name = 'sam')
frank = Dog(breed = 'Huski', name = 'frank')
# Out:
# mammal
# mammal

# %%
sam.bark()
# Out:
# wooof!

# %%
class Animal:
    def __init__(self):
        print('Animal Created')
    def whoAmI(self):
        print('Animal')
    def eat(self):
        print('Eating')

class Dog(Animal):
    def __init__(self):
        Animal.__init__(self)
        print('Dog Created')
    def whoAmI(self):
        print('Dog')
    def bark(self):
        print('Wooof')

# %%
d = Dog()
# Out:
# Animal Created
# Dog Created

# %%
d.whoAmI()
# Out:
# Dog

# %%
d.eat()
# Out:
# Eating

# %%
d.bark()
# Out:
# Wooof

# %%
a = Animal()
# Out:
# Animal Created

# %%
a.bark()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a.bark()
#
# AttributeError: 'Animal' object has no attribute 'bark'

# %%
class Animal:
    def __init__(self):
        print('Animal Created')
    def whoAmI(self):
        print('Animal')
    def eat(self):
        print('Eating')

class Dog(Animal):
    def __init__(self):
        Animal.__init__(self)
        print('Dog Created')
    def whoAmI(self):
        print('Dog')
    def bark(self):
        print('Wooof')

class Lion(Animal):
        def __init__(self):
            Animal.__init__(self)
            print('Lion Created')

# %%
l = Lion()
# Out:
# Animal Created
# Lion Created

# %%
l.whoAmI()
# Out:
# Animal

# %%
class Dog:
    def __init__(self, name):
        self.name = name
    def speak(self):
        return self.name + ' says Woof!'

class Cat:
    def __init__(self, name):
        self.name = name
    def speak(self):
        return self.name + ' says Meow!'

# %%
class Dog:
    def __init__(self, name):
        self.name = name
    def speak(self):
        return self.name + ' says Woof!'

class Cat:
    def __init__(self, name):
        self.name = name
    def speak(self):
        return self.name + ' says Meow!'

niko = Dog('Niko')
felix = Cat('Felix')

print(niko.speak())
print(felix.speak())
# Out:
# Niko says Woof!
# Felix says Meow!

# %%
for pet in [niko, felix]:
    print(pet.speak())
# Out:
# Niko says Woof!
# Felix says Meow!

# %%
def pet_speak(pet):
    print(pet.speak())

pet_speak(niko)
pet_speak(felix)
# Out:
# Niko says Woof!
# Felix says Meow!

# %%
class Animal:
    def __init__(self, name):
        self.name = name
    def speak(self):
        pass

# %%
class Animal:
    def __init__(self, name):
        self.name = name
    def speak(self):
        raise NotImplementedError('Subclass must implement speak() method.')

# %%
class Animal:
    def __init__(self, name):
        self.name = name
    def speak(self):
        raise NotImplementedError('Subclass must implement speak() method.')

class Dog(Animal):
    def speak(self):
        return self.name + ' says Woof!'

class Cat(Animal):
    def speak(self):
        return self.name + ' says Meow!'

# %%
class Animal:
    def __init__(self, name):
        self.name = name
    def speak(self):
        raise NotImplementedError('Subclass must implement speak() method.')

class Dog(Animal):
    def speak(self):
        return self.name + ' says Woof!'

class Cat(Animal):
    def speak(self):
        return self.name + ' says Meow!'

fido = Dog('Fido')
isis = Cat('Isis')

print(fido.speak())
print(isis.speak())
# Out:
# Fido says Woof!
# Isis says Meow!

# %%
class Book:
    def __init__(self, title, author, pages):
        print('A book is created.')
        self.title = title
        self.author = author
        self.pages = pages

book = Book('Python Rocks!', 'J. P.', 209)
# Out:
# A book is created.

# %%
print(book)
# Out:
# <__main__.Book object at 0x000002598F8EFE00>

# %%
class Book:
    def __init__(self, title, author, pages):
        print('A book is created.')
        self.title = title
        self.author = author
        self.pages = pages
    def __str__(self):
        return f"Title: {self.title}, author: {self.author}, pages: {self.pages}"

book = Book('Python Rocks!', 'J. P.', 209)

print(book)
# Out:
# A book is created.
# Title: Python Rocks!, author: J. P., pages: 209

# %%
len(book)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 len(book)
#
# TypeError: object of type 'Book' has no len()

# %%
class Book:
    def __init__(self, title, author, pages):
        print('A book is created.')
        self.title = title
        self.author = author
        self.pages = pages
    def __str__(self):
        return f"Title: {self.title}, author: {self.author}, pages: {self.pages}"
    def __len__(self):
        return self.pages

book = Book('Python Rocks!', 'J. P.', 209)

len(book)
# Out:
# A book is created.
# 209

# %%
class Line:
    def __init__(self, coor1, coor2):
        self.coor1 = coor1
        self.coor2 = coor2
    def distance(self):
        x1, y1 = self.coor1
        x2, y2 = self.coor2
        return ((x2-x1)**2 + (y2-y1)**2)**0.5
    def slop(self):
        x1, y1 = self.coor1
        x2, y2 = self.coor2
        return (y2-y1)/(x2-x1)


coordinate1 = (3, 2)
coordinate2 = (8, 10)

li = Line(coordinate1, coordinate2)

# %%
li.distance()
# Out:
# 9.433981132056603

# %%
li.slop()
# Out:
# 1.6

# %%
class Cylinder:
    def __init__(self, height = 1, radius = 1):
        self.height = height
        self.radius = radius
    def volume(self):
        return self.height * (3.14 * self.radius**2)
    def surface_area(self):
        top = 3.14 * (self.radius)**2
        return (2 * top) + (2*3.14*self.radius*self.height)


c = Cylinder(2, 3)

c.volume()
# Out:
# 56.52

# %%
c.surface_area()
# Out:
# 94.2

# %%
c2 = Cylinder()
c2.volume()
# Out:
# 3.14

# %%
class Account:
    def __init__(self, owner, balance = 0):
        self.owner = owner
        self.balance = balance
    def __str__(self):
        return f"Account Owner: {self.owner} \nAccount Balance: {self.balance}"
    def deposit(self, dep_amt):
        self.balance += dep_amt
        print('Deposit Accepted!')
    def withdraw(self, wd_amt):
        if self.balance >= wd_amt:
            self.balance -= wd_amt
            print('Withdrawal Accepted!')
        else:
            print('Fund Unavailable!!')

# %%
acct1 = Account('Jose', 100)
print(acct1)
# Out:
# Account Owner: Jose
# Account Balance: 100

# %%
acct1.owner
# Out:
# 'Jose'

# %%
acct1.balance
# Out:
# 100

# %%
acct1.deposit(50)
# Out:
# Deposit Accepted!

# %%
print(acct1)
# Out:
# Account Owner: Jose
# Account Balance: 150

# %%
acct1.withdraw(75)
# Out:
# Withdrawal Accepted!

# %%
print(acct1)
# Out:
# Account Owner: Jose
# Account Balance: 75

# %%
acct1.withdraw(500)
# Out:
# Fund Unavailable!!

# %%
class Account:
    def __init__(self, owner, balance = 0):
        self.owner = owner
        self._balance = balance
    def __str__(self):
        return f"Account Owner: {self.owner} \nAccount Balance: {self._balance}"
    def get_balance(self):
        return self._balance
    def deposit(self, dep_amt):
        self._balance += dep_amt
        print('Deposit Accepted!')
    def withdraw(self, wd_amt):
        if self._balance >= wd_amt:
            self._balance -= wd_amt
            print('Withdrawal Accepted!')
        else:
            print('Fund Unavailable!!')

# %%
acct1 = Account('Jose', 100)
acct1.get_balance()
# Out:
# 100

# %%
acct1._balance
# Out:
# 100

# %%
class Sample:
    def __init__(self):
        self.__x = 1
        self.y = 2
    def __foo(self):
        print('This is a private method.')
    def bar(self):
        print('This is a public method.')
        self.__foo()

obj1 = Sample()

# %%
obj1.y
# Out:
# 2

# %%
obj1.__x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 obj1.__x
#
# AttributeError: 'Sample' object has no attribute '__x'

# %%
vars(obj1)
# Out:
# {'_Sample__x': 1, 'y': 2}

# %%
obj1._Sample__x
# Out:
# 1

# %%
class ObjectCounter:
    num_instance = 0
    def __init__(self):
        type(slef).num_instance += 1

# %%
class ObjectCounter:
    num_instance = 0
    def __init__(self):
        ObjectCounter.num_instance += 1

# %%
x1 = ObjectCounter()
x2 = ObjectCounter()
x3 = ObjectCounter()
x4 = ObjectCounter()

# %%
ObjectCounter.num_instance
# Out:
# 4

# %%
counter = ObjectCounter()
counter.num_instance
# Out:
# 5

# %%
class ObjectCounter:
    num_instance = 0
    def __init__(self):
        self.num_instance += 1

# %%
ObjectCounter()
ObjectCounter()
ObjectCounter()
ObjectCounter()

ObjectCounter.num_instance
# Out:
# 0

# %%
x1 = ObjectCounter()
x2 = ObjectCounter()
x3 = ObjectCounter()
x4 = ObjectCounter()

ObjectCounter.num_instance
# Out:
# 0

# %%
x1.num_instance
# Out:
# 1

# %%
class Car:
    def __init__(self, make, model, year, color):
        self.make = make
        self.model = model
        self.year = year
        self.color = color
        self.started = False
        self.speed = 0
        self.max_speed = 200

# %%
toyota_camry = Car("Toyota", "Camry", 2022, "Red")
ford_mustang = Car("Ford", "Mustang", 2022, "Black")

# %%
print(toyota_camry.make, toyota_camry.model, toyota_camry.year, toyota_camry.max_speed)
# Out:
# Toyota Camry 2022 200

# %%
print(ford_mustang.make, ford_mustang.model, ford_mustang.year, ford_mustang.max_speed)
# Out:
# Ford Mustang 2022 200

# %%
Car.make
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Car.make
#
# AttributeError: type object 'Car' has no attribute 'make'

# %%
class SampleClass:
    class_attr = 100
    def __init__(self, instance_attr):
        self.instance_attr = instance_attr
    def method(self):
        print(f"Class Attribute: {self.class_attr}")
        print(f"Instance Attribute: {self.instance_attr}")

# %%
SampleClass.class_attr
# Out:
# 100

# %%
SampleClass.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'class_attr': 100,
#               '__init__': <function __main__.SampleClass.__init__(self, instance_attr)>,
#               'method': <function __main__.SampleClass.method(self)>,
#               '__static_attributes__': ('instance_attr',),
#               '__dict__': <attribute '__dict__' of 'SampleClass' objects>,
#               '__weakref__': <attribute '__weakref__' of 'SampleClass' objects>,
#               '__doc__': None})

# %%
SampleClass.__dict__['class_attr']
# Out:
# 100

# %%
instance = SampleClass("Hello!")

# %%
instance.instance_attr
# Out:
# 'Hello!'

# %%
instance.method()
# Out:
# Class Attribute: 100
# Instance Attribute: Hello!

# %%
instance.__dict__
# Out:
# {'instance_attr': 'Hello!'}

# %%
instance.__dict__["instance_attr"]
# Out:
# 'Hello!'

# %%
instance.__dict__["instance_attr"] = 'Goodbye!'

# %%
instance.instance_attr
# Out:
# 'Goodbye!'

# %%
class Record:
    """Hold a record of data."""

# %%
john = {
    'name': 'John Doe',
    'position': 'Python Developer',
    'department': 'engineering',
    'salary': 80000,
    'hire_date': '2020-01-01',
    "is_manager": False,
}

# %%
john_record = Record()

for field, value in john.items():
    setattr(john_record, field, value)

# %%
john_record.name
# Out:
# 'John Doe'

# %%
john_record.department
# Out:
# 'engineering'

# %%
john_record.__dict__
# Out:
# {'name': 'John Doe',
#  'position': 'Python Developer',
#  'department': 'engineering',
#  'salary': 80000,
#  'hire_date': '2020-01-01',
#  'is_manager': False}

# %%
class User:
    pass

jane = User()

jane.name = "Jane Doe"
jane.job = "Data Engineer"
jane.__dict__
# Out:
# {'name': 'Jane Doe', 'job': 'Data Engineer'}

# %%
#Add methods dynamically
def __init__(self, name, job):
    self.name = name
    self.job = job

User.__init__ = __init__
User.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'User' objects>,
#               '__weakref__': <attribute '__weakref__' of 'User' objects>,
#               '__doc__': None,
#               '__init__': <function __main__.__init__(self, name, job)>})

# %%
linda = User('Linda Smith', 'Team Leader')
linda.__dict__
# Out:
# {'name': 'Linda Smith', 'job': 'Team Leader'}

# %%
class ThreeDPoint:
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z
    def __iter__(sekf):
        yield from (self.x, self.y, self.z)

    @classmethod
    def from_sequence(cls, sequence):
        return cls(*sequence)
        
    def __repr__(self):
        return f"{type(self).__name__} ({self.x}, {self.y}, {self.z})"

# %%
yy = ThreeDPoint(9, -6, 3)
yy
# Out:
# ThreeDPoint (9, -6, 3)

# %%
x = ThreeDPoint.from_sequence((4, 8, 16))
x
# Out:
# ThreeDPoint (4, 8, 16)

# %%
point = ThreeDPoint(7, 14, 21)
point.from_sequence((3, 6, 9))
# Out:
# ThreeDPoint (3, 6, 9)

# %%
point
# Out:
# ThreeDPoint (7, 14, 21)

# %%
class ThreeDPoint:
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z
    def __iter__(sekf):
        yield from (self.x, self.y, self.z)

    @classmethod
    def from_sequence(cls, sequence):
        return cls(*sequence)

    @staticmethod
    def show_into_message(name):
        print(f"Hey {name}! This is your 3D Point.")
        
    def __repr__(self):
        return f"{type(self).__name__} ({self.x}, {self.y}, {self.z})"

# %%
ThreeDPoint.show_into_message('Pythonista')
# Out:
# Hey Pythonista! This is your 3D Point.

# %%
point = ThreeDPoint(2, 4, 6)
point.show_into_message('Python developer')
# Out:
# Hey Python developer! This is your 3D Point.

# %%
class Person:
    def __init__(self, name):
        self.set_name(name)
    def get_name(self):
        return self._name
    def set_name(self, value):
        self._name = value

# %%
jane = Person('Jane')
jane.get_name()
# Out:
# 'Jane'

# %%
jane.set_name('Jane Doe')
jane.get_name()
# Out:
# 'Jane Doe'

# %%
vars(jane)
# Out:
# {'_name': 'Jane Doe'}

# %%
jane._name
# Out:
# 'Jane Doe'

# %%
class Person:
    def __init__(self, name):
        self.name = name

jane = Person('Jane')
jane.name
# Out:
# 'Jane'

# %%
jane.name = "Jane Doe"
jane.name
# Out:
# 'Jane Doe'

# %%
class Person:
    def __init__(self, name):
        self.name = name

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self, value):
        self._name = value.upper()

# %%
jane = Person('Jane')
jane.name
# Out:
# 'JANE'

# %%
vars(jane)
# Out:
# {'_name': 'JANE DOE'}

# %%
jane.name = "Jane Doe"
jane.name
# Out:
# 'JANE DOE'

# %%
from dataclasses import dataclass

@dataclass
class ThreeDPoint:
    x: int | float
    y: int | float
    z: int | float

    @classmethod
    def from_sequence(cls, sequence):
        return cls(*sequence)

    @staticmethod
    def show_intro_message(name):
        print(f"Hey {name}! This is your 3D Point.")

# %%
point_1 = ThreeDPoint(1.0, 2.0, 3.0)
point_2 = ThreeDPoint(2, 3, 4)

point_1 == point_2
# Out:
# False

# %%
point_3 = ThreeDPoint(1, 2, 3)

point_1 == point_3
# Out:
# True

# %%
point_1
# Out:
# ThreeDPoint(x=1.0, y=2.0, z=3.0)

# %%
point_3
# Out:
# ThreeDPoint(x=1, y=2, z=3)

# %%
from dataclasses import astuple

astuple(point_1)
# Out:
# (1.0, 2.0, 3.0)

# %%
from enum import Enum

class WeekDay(Enum):
    MONDAY = 1
    TUESDAY = 2
    WEDNESDAY = 3
    THURSDAY = 4
    FRIDAY = 5
    SATURDAY = 6
    SUNDAY = 7

# %%
WeekDay.MONDAY = 0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 WeekDay.MONDAY = 0
#
# File C:\ProgramData\anaconda3\Lib\enum.py:839, in EnumType.__setattr__(cls, name, value)
#     837 member_map = cls.__dict__.get('_member_map_', {})
#     838 if name in member_map:
# --> 839     raise AttributeError('cannot reassign member %r' % (name, ))
#     840 super().__setattr__(name, value)
#
# AttributeError: cannot reassign member 'MONDAY'

# %%
list(WeekDay)
# Out:
# [<WeekDay.MONDAY: 1>,
#  <WeekDay.TUESDAY: 2>,
#  <WeekDay.WEDNESDAY: 3>,
#  <WeekDay.THURSDAY: 4>,
#  <WeekDay.FRIDAY: 5>,
#  <WeekDay.SATURDAY: 6>,
#  <WeekDay.SUNDAY: 7>]

# %%
WeekDay.MONDAY
# Out:
# <WeekDay.MONDAY: 1>

# %%
WeekDay(2)
# Out:
# <WeekDay.TUESDAY: 2>

# %%
WeekDay['WEDNESDAY']
# Out:
# <WeekDay.WEDNESDAY: 3>

# %%
WeekDay.THURSDAY.name
# Out:
# 'THURSDAY'

# %%
WeekDay.THURSDAY.value
# Out:
# 4

# %%
for day in WeekDay:
    print(day.name, "->", day.value)
# Out:
# MONDAY -> 1
# TUESDAY -> 2
# WEDNESDAY -> 3
# THURSDAY -> 4
# FRIDAY -> 5
# SATURDAY -> 6
# SUNDAY -> 7

# %%
from enum import Enum

class WeekDay(Enum):
    MONDAY = 1
    TUESDAY = 2
    WEDNESDAY = 3
    THURSDAY = 4
    FRIDAY = 5
    SATURDAY = 6
    SUNDAY = 7

    @classmethod
    def favorite_day(cls):
        return cls.FRIDAY

    def __str__(self):
        return f"Current day: {self.name}"

# %%
WeekDay.favorite_day()
# Out:
# <WeekDay.FRIDAY: 5>

# %%
print(WeekDay.FRIDAY)
# Out:
# Current day: FRIDAY

# %%
class Animal:
    def __init__(self, name, sex, habitat):
        self.name = name
        self.sex = sex
        self.habitat = habitat

class Mammal(Animal):
    unique_feature = "Mammary glands"

class Bird(Animal):
    unique_feature = "Feathers"

class Fish(Animal):
    unique_feature = "Gills"

class Dog(Mammal):
    def walk(self):
        print("The dog is walking")

class Cat(Mammal):
    def walk(self):
        print("The cat is walking")

class Eagle(Bird):
    def fly(self):
        print("The eagle is flying")

class Penguin(Bird):
    def swim(self):
        print("The penguin is swimming")

class Salmon(Fish):
    def swim(self):
        print("The salmon is swimming")

class Shark(Fish):
    def swim(self):
        print("The shark is swimming")

# %%
class Aircraft:
    def __init__(self, thrust, lift, max_speed):
        self.thrust = thrust
        self.lift = lift
        self.max_speed = max_speed

    def show_technical_spec(self):
        print(f"Thrust: {self.thrust} KW")
        print(f"Lift: {self.lift} Kg")
        print(f"Max Speed: {self.max_speed} km/h")

# %%
class Helicopter(Aircraft):
    def __init__(self, thrust, lift, max_speed, num_rotors):
        super().__init__(thrust, lift, max_speed)
        self.num_rotors = num_rotors

    def show_technical_spec(self):
        super().show_technical_spec()
        print(f"Number of rotos: {self.num_rotors}")

# %%
h1 = Helicopter(25, 300, 150, 2)

h1

# %%
sikorsky_UH60 = Helicopter(1490, 9979, 278, 2)
sikorsky_UH60.show_technical_spec()
# Out:
# Thrust: 1490 KW
# Lift: 9979 Kg
# Max Speed: 278 km/h
# Number of rotos: 2

# %%
class Worker:
    def __init__(self, name, address, hourly_salary):
        self.name = name
        sel.address = address
        self.hourly_salary = hourly_salary

    def show_profile(self):
        print("== Worker Profile ==")
        print(f"Name: {self.name}")
        print(f"Address: {self.address}")
        print(f"Hourly Salary: {self.hourly_salary}")

    def calculate_payroll(self, hours = 40):
        return self.hourly_salary * hours

# %%
class Manager(Worker):
    def __init__(self, name, address, hourly_salary, hourly_bonus):
        super().__init__(name, address, hourly_salary)
        self.hourly_bonus = hourly_bonus

    def calculate_payroll(self, hours = 40):
        return (self.hourly_salary + self.hourly_bonus) * hours

# %%
class Vehicle:
    def __init__(self, make, model, color):
        self.make = make
        self.model = model
        self.color = color

    def start(self):
        print("Starning the engine...")

    def stop(self):
        print("Stopping the engine...")

    def show_technical_spec(self):
        print(f"Make: {self.make}")
        print(f"Model: {self.model}")
        print(f"Color: {self.color}")

class Car(Vehicle):
    def drive(self):
        print("Driving on the road...")

class Aircraft(Vehicle):
    def fly(self):
        print("Flying in the sky...")

class FlyingCar(Car, Aircraft):
    pass

# %%
space_flyer = FlyingCar("Space", "Flyer", "Black")
space_flyer.show_technical_spec()
# Out:
# Make: Space
# Model: Flyer
# Color: Black

# %%
space_flyer.start()
# Out:
# Starning the engine...

# %%
space_flyer.drive()
# Out:
# Driving on the road...

# %%
space_flyer.fly()
# Out:
# Flying in the sky...

# %%
class A:
    def method(self):
        print("A.method")

class B(A):
    def method(self):
        print("B.method")

class C(A):
    def method(self):
        print("C.method")

class D(B, C):
    pass

# %%
D().method()
# Out:
# B.method

# %%
D.__mro__
# Out:
# (__main__.D, __main__.B, __main__.C, __main__.A, object)

# %%
import json
import pickle

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class SerializerMixin:
    def to_json(self):
        return json.dumps(self.__dict__)

    def to_pickle(self):
        return pickle.dumps(self.__dict__)

class Employee(SerializerMixin, Person):
    def __init__(self, name, age, salary):
        super().__init__(name, age)
        self.salary = salary

# %%
john = Employee("John Doe", 30, 50000)
john.to_json()
# Out:
# '{"name": "John Doe", "age": 30, "salary": 50000}'

# %%
john.to_pickle()
# Out:
# b'\x80\x04\x95+\x00\x00\x00\x00\x00\x00\x00}\x94(\x8c\x04name\x94\x8c\x08John Doe\x94\x8c\x03age\x94K\x1e\x8c\x06salary\x94MP\xc3u.'

# %%
class IndustrialRobot:
    def __init__(self):
        self.body = Body()
        self.arm = Arm()

    def rotate_body_left(self, degrees = 10):
        self.body.rotate_left(degrees)

    def rotate_body_right(self, degrees = 10):
        self.body.rotate_right(degrees)

    def move_arm_up(self, distance = 1):
        self.arm.move_up(distance)

    def move_arm_down(self, distance = 1):
        self.arm.move_down(distance)

    def weld(self):
        self.arm.weld()

class Body:
    def __init__(self):
        self.rotation = 0

    def rotate_left(self, degrees = 10):
        self.rotation -= degrees
        print(f"Rotating body {degrees} degress to the left...")

    def rotate_right(self, degrees = 10):
        self.rotation += degrees
        print(f"Rotating body {degrees} degress to the right...")

class Arm:
    def __init__(self):
        self.position = 0

    def move_up(self, distance = 1):
        self.position += distance
        print(f"Moving arm {distance} cm up...")

    def move_down(self, distance = 1):
        self.position -= distance
        print(f"Moving arm {distance} cm down...")

    def weld(self):
        print("Welding...")

# %%
robot = IndustrialRobot()
robot

# %%
robot.rotate_body_left()
# Out:
# Rotating body 10 degress to the left...

# %%
robot.move_arm_up(15)
# Out:
# Moving arm 15 cm up...

# %%
robot.move_arm_up(15)
# Out:
# Moving arm 15 cm up...

# %%
robot.rotate_body_right(20)
# Out:
# Rotating body 20 degress to the right...

# %%
robot.move_arm_down(5)
# Out:
# Moving arm 5 cm down...

# %%
robot.weld()
# Out:
# Welding...

# %%
vars(robot)
# Out:
# {'body': <__main__.Body at 0x210775b82f0>,
#  'arm': <__main__.Arm at 0x210775b8440>}

# %%
robot.body

# %%
robot.body.rotation
# Out:
# 10

# %%
robot.arm.position
# Out:
# 25

# %%
class Stack:
    def __init__(self, items = None):
        if items is None:
            self._items = []
        else:
            self._items = list(items)

    def push(self, item):
        self._items.append(item)

    def pop(self):
        return self._items.pop()

    def __repr__(self) -> str:
        return f"{type(self).__name__}({self._items})"

# %%
stack = Stack([1, 2, 3])
stack
# Out:
# Stack([1, 2, 3])

# %%
stack.push(4)
stack
# Out:
# Stack([1, 2, 3, 4, 4])

# %%
stack.pop()
# Out:
# 4

# %%
stack.pop()
# Out:
# 3

# %%
dir(stack)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_items',
#  'pop',
#  'push']

# %%
class Stack(list):
    def push(self, item):
        self.append(item)
    def pop(self):
        return super().pop()
    def __repr__(self) -> str:
        return f"{type(self).__name__}({super().__repr__()})"

stack = Stack()
dir(stack)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'push',
#  'remove',
#  'reverse',
#  'sort']

# %%
import json
import pickle

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class Serializer:
    def __init__(self, instance):
        self.instance = instance
        
    def to_json(self):
        return json.dumps(self.instance.__dict__)

    def to_pickle(self):
        return pickle.dumps(self.instance.__dict__)

class Employee(Person):
    def __init__(self, name, age, salary):
        super().__init__(name, age)
        self.salary = salary

    def __getattr__(self, attr):
        return getattr(Serializer(self), attr)

# %%
class IndustrialRobot:
    #def __init__(self):
        #self.body = Body()
        #self.arm = Arm()
    def __init__(self, body, arm):
        self.body = body
        self.arm = arm

    def rotate_body_left(self, degrees = 10):
        self.body.rotate_left(degrees)

    def rotate_body_right(self, degrees = 10):
        self.body.rotate_right(degrees)

    def move_arm_up(self, distance = 1):
        self.arm.move_up(distance)

    def move_arm_down(self, distance = 1):
        self.arm.move_down(distance)

    def weld(self):
        self.arm.weld()

class Body:
    def __init__(self):
        self.rotation = 0

    def rotate_left(self, degrees = 10):
        self.rotation -= degrees
        print(f"Rotating body {degrees} degress to the left...")

    def rotate_right(self, degrees = 10):
        self.rotation += degrees
        print(f"Rotating body {degrees} degress to the right...")

class Arm:
    def __init__(self):
        self.position = 0

    def move_up(self, distance = 1):
        self.position += distance
        print(f"Moving arm {distance} cm up...")

    def move_down(self, distance = 1):
        self.position -= distance
        print(f"Moving arm {distance} cm down...")

    def weld(self):
        print("Welding...")

# %%
robot = IndustrialRobot(Body(), Arm())

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def get_area(self):
        pass

    @abstractmethod
    def get_perimeter(self):
        pass

# %%
from abc import ABC, abstractmethod
from math import pi

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def get_area(self):
        return pi*self.radius**2

# %%
circle = Circle(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 circle = Circle(100)
#
# TypeError: Can't instantiate abstract class Circle without an implementation for abstract method 'get_perimeter'

# %%
from abc import ABC, abstractmethod
from math import pi

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def get_area(self):
        return pi*self.radius**2

    def get_perimeter(self):
        return 2*pi*self.radius

# %%
circle = Circle(100)

# %%
circle.radius
# Out:
# 100

# %%
circle.get_area()
# Out:
# 31415.926535897932

# %%
circle.get_perimeter()
# Out:
# 628.3185307179587

# %%
class Square(Shape):
    def __init__(self, side):
        self.side = side

    def get_area(self):
        return self.side**2

    def get_perimeter(self):
        return 4*self.side
