# %%
my_file = open('test.txt')

# %%
my_file.read()
# Out:
# '%%writefile test.txt\nHello, this is a quick test file.\nOverwriting test.txt'

# %%
my_file.read()
# Out:
# ''

# %%
my_file.readline()
# Out:
# ''

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.read()
# Out:
# 'Hello, this is a quick test file.\nOverwriting test.txt'

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.read()
# Out:
# 'Hello, this is a quick test file.\nThere is a new line here.\nAt the moment.'

# %%
my_file.readline()
# Out:
# ''

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.readline()
# Out:
# 'Hello, this is a quick test file.\n'

# %%
my_file.seek(0)
my_file.readlines()
# Out:
# ['Hello, this is a quick test file.\n',
#  'There is a new line here.\n',
#  'At the moment.']

# %%
my_file.close()

# %%
my_file = open('test.txt')

# %%
my_file.readlines()
# Out:
# ['Hello, this is a quick test file.\n',
#  'There is a new line here.\n',
#  'At the moment.\n',
#  '\n',
#  '\n',
#  'Hello, this is a quick test file.\n',
#  '\n',
#  'Hello, this is a quick test file 555.']

# %%
my_file.close()

# %%
my_file = open('test.txt', 'w+')

# %%
my_file.write('This is a new sentence that I have written.')
# Out:
# 43

# %%
my_file.seek(0)
my_file.read()
# Out:
# 'This is a new sentence that I have written.'

# %%
my_file.close()

# %%
my_file = open('test.txt', 'a+')
my_file.write('\nThis is text being appended to test.txt')
my_file.write('\nAnd another line here.')
# Out:
# 23

# %%
my_file.seek(0)
print(my_file.read())
# Out:
# This is a new sentence that I have written.
# This is text being appended to test.txt
# And another line here.

# %%
my_file.close()

# %%
# %%writefile test.txt
# "This is text being appended to test."
# "another line here."
# Out:
# Overwriting test.txt

# %%
# %%writefile test.txt
# First line
# Second line
# Out:
# Overwriting test.txt

# %%
# %%writefile -a test.txt
#
# This is text being appended to test.txt
# And another line here.
# Appending to test.txt
# Out:
# Appending to test.txt

# %%
for line in open('test.txt'):
    print(line)
# Out:
# First line
#
# Second line
#
#
#
# This is text being appended to test.txt
#
# And another line here.
#
# Appending to test.txt

# %%
5*50/2-5**5+0.25
# Out:
# -2999.75

# %%
((5*50)/2) - (5**5) + 0.25
# Out:
# -2999.75

# %%
((5*50)/2) - ((5**5) + 0.25)
# Out:
# -3000.25

# %%
((5*50)/2) - (5**5 + 0.25)
# Out:
# -3000.25

# %%
5*50/2 + 0.25 - 5**5
# Out:
# -2999.75

# %%
5*50/2 + 0.25
# Out:
# 125.25

# %%
5**2
# Out:
# 25

# %%
5*50/2-5**2+0.25
# Out:
# 100.25

# %%
(60+(10**2)/4*7)-134.75
# Out:
# 100.25

# %%
(5+6)*4
# Out:
# 44

# %%
5+6*4
# Out:
# 29

# %%
5*6+4
# Out:
# 34

# %%
type(4+1.5+3)
# Out:
# float

# %%
x = 25
x**1/2
# Out:
# 12.5

# %%
x = 25
x**(1/2)
# Out:
# 5.0

# %%
x = 25
x ** 0.5
# Out:
# 5.0

# %%
s = 'hello'
s[1]
# Out:
# 'e'

# %%
'hello'[1]
# Out:
# 'e'

# %%
s[::-1]
# Out:
# 'olleh'

# %%
'hello'[: : -1]
# Out:
# 'olleh'

# %%
'hello'[4]
# Out:
# 'o'

# %%
'hello'[-1]
# Out:
# 'o'

# %%
list1 = [0]
list2 = list1+[0]
list3 = list2 + [0]
list3
# Out:
# [0, 0, 0]

# %%
list1 = [0]
list1.append(0)
list1.append(0)
list1.append(0)
list1
# Out:
# [0, 0, 0, 0]

# %%
list1 = [0]
list1 += [0, 0]
list1
# Out:
# [0, 0, 0]

# %%
[0]*3
# Out:
# [0, 0, 0]

# %%
list1 = list([0, 0, 0, 0])
list1
# Out:
# [0, 0, 0, 0]

# %%
([0, 0])
# Out:
# [0, 0]

# %%
list3 = [1, 2, [3, 4, 'hello']]
list3[2][2] = 'goodbye'
list3
# Out:
# [1, 2, [3, 4, 'goodbye']]

# %%
list3 = [1, 2, [3, 4, 'hello']]
list3.pop()
# Out:
# [3, 4, 'hello']

# %%
list4 = [5, 3, 4, 6, 1]
list4.sort()
list4
# Out:
# [1, 3, 4, 5, 6]

# %%
list4 = [5, 3, 4, 6, 1]
list4.sort(reverse = True)
list4
# Out:
# [6, 5, 4, 3, 1]

# %%
list4 = [5, 3, 4, 6, 1]
sorted(list4)
# Out:
# [1, 3, 4, 5, 6]

# %%
d = {'simple_key' : 'hello'}
d['simple_key']
# Out:
# 'hello'

# %%
d = {'k1': {'k2' : "hello"}}
d['k1']['k2']
# Out:
# 'hello'

# %%
d = {'k1':[{'nest_key':['this is deep', ['hello']]}]}
d['k1'][0]['nest_key'][1]
# Out:
# ['hello']

# %%
d = {'k1':[{'nest_key':['this is deep', ['hello']]}]}
d['k1'][0]['nest_key'][1][0]
# Out:
# 'hello'

# %%
d = {'k1':[1, 2, {'k2':['this is tricky',{'tough':[1, 2, ['hello']]}]}]}
d['k1'][2]['k2'][1]['tough'][2][0]
# Out:
# 'hello'

# %%
list5 = [1, 2, 2, 33, 4, 4, 11, 22, 3, 3, 2]
unique = set(list5)
unique
# Out:
# {1, 2, 3, 4, 11, 22, 33}

# %%
list(unique)
# Out:
# [1, 2, 33, 4, 3, 11, 22]

# %%
2 == 2
# Out:
# True

# %%
2 == 1
# Out:
# False

# %%
x = 0.1 + 0.2
x == 0.3
# Out:
# False

# %%
x
# Out:
# 0.30000000000000004

# %%
tolerance = 0.001
x = 0.1 + 0.2
abs(x - 0.3) < tolerance
# Out:
# True

# %%
2 != 1
# Out:
# True

# %%
2!= 2
# Out:
# False

# %%
2 > 1
# Out:
# True

# %%
2 > 4
# Out:
# False

# %%
2 < 4
# Out:
# True

# %%
2 < 1
# Out:
# False

# %%
2 >= 2
# Out:
# True

# %%
2 >= 1
# Out:
# True

# %%
2 <= 2
# Out:
# True

# %%
2 <= 4
# Out:
# True

# %%
l = [1, 3, 5, 7, 9]
1 in l
# Out:
# True

# %%
2 in l
# Out:
# False

# %%
2 not in l
# Out:
# True

# %%
l = [1, 2, 3, 4]
l1 = [1, 2, 3, 4]
l is l1
# Out:
# False

# %%
id(l)
# Out:
# 2273337761280

# %%
id(l1)
# Out:
# 2273337663936

# %%
l2 = l
l2 is l
# Out:
# True

# %%
id(l2)
# Out:
# 2273337761280

# %%
l is not l1
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
1 > 3
# Out:
# False

# %%
not 1 > 3
# Out:
# True

# %%
1 < 2 and 2 == 2
# Out:
# True

# %%
2 > 5 and 100 != 5
# Out:
# False

# %%
2 > 5 or 100 != 5
# Out:
# True

# %%
2 > 5 or 100 != 100
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(' ')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool([ ])
# Out:
# False

# %%
bool(())
# Out:
# False

# %%
bool(( ))
# Out:
# False

# %%
bool({})
# Out:
# False

# %%
bool({ })
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool(55)
# Out:
# True

# %%
bool('hi')
# Out:
# True

# %%
bool([1, 2])
# Out:
# True

# %%
2 < 0 or 2 or 5 > -5 or True
# Out:
# 2

# %%
2 < 0 or 0 or 5 > -5 or True
# Out:
# True

# %%
2 < 0 or 0 or 5 < -5 or []
# Out:
# []

# %%
5 < 17 and 4 > 8 and True
# Out:
# False

# %%
5 < 17 and 0 and True
# Out:
# 0

# %%
5 < 17 and 4 > -8 and 'hello'
# Out:
# 'hello'

# %%
1 < 2 < 3
# Out:
# True

# %%
1 < 2 and 2 < 3
# Out:
# True

# %%
1 < 3 > 2
# Out:
# True

# %%
1 < 3 and 3 > 2
# Out:
# True

# %%
x = input('Enter a name: ') or 'Empty'
# Out:
# Enter a name:  hello

# %%
x
# Out:
# 'hello'
