# %%
4*10^2
# Out:
# 42

# %%
4*10**2
# Out:
# 400

# %%
1+2
# Out:
# 3

# %%
5-7
# Out:
# -2

# %%
5*5
# Out:
# 25

# %%
14/2
# Out:
# 7.0

# %%
15/2
# Out:
# 7.5

# %%
15//2
# Out:
# 7

# %%
17%5
# Out:
# 2

# %%
5%13
# Out:
# 5

# %%
5**2
# Out:
# 25

# %%
25**0.5
# Out:
# 5.0

# %%
25**1/2
# Out:
# 12.5

# %%
25**(1/2)
# Out:
# 5.0

# %%
27**0.3
# Out:
# 2.6878753795222865

# %%
27**(1/3)
# Out:
# 3.0

# %%
27**0.33
# Out:
# 2.9672220125165123

# %%
27**0.3333
# Out:
# 2.999670434416971

# %%
2+10*10+3
# Out:
# 105

# %%
2+(10*10)+3
# Out:
# 105

# %%
(2+10)*10+3
# Out:
# 123

# %%
(2+10)*(10+3)
# Out:
# 156

# %%
5*12/6*2
# Out:
# 20.0

# %%
a = 5
a*a
# Out:
# 25

# %%
a**a
# Out:
# 3125

# %%
a = 15
a
# Out:
# 15

# %%
a = a + a
a
# Out:
# 30

# %%
income = 100
rate = 0.1
tax = income * rate
tax
# Out:
# 10.0

# %%
a = 5
b = (1, 2)
c = [1, 3]
d = {5, 6}
e = '5'
f = 2.398
print(a, b, c, d, e, f)
type(a, b, c, d, e, f)
# Out:
# 5 (1, 2) [1, 3] {5, 6} 5 2.398
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 8
#       6 f = 2.398
#       7 print(a, b, c, d, e, f)
# ----> 8 type(a, b, c, d, e, f)
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(a)
type(b)
type(c)
type(d)
type(e)
type(f)
# Out:
# float

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# tuple

# %%
type(c)
# Out:
# list

# %%
type(d)
# Out:
# set

# %%
type(e)
# Out:
# str

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
# Out:
# <class 'str'>
# <class 'tuple'>
# <class 'list'>
# <class 'set'>
# <class 'str'>
# <class 'float'>

# %%
a = 'hello'
print(a)
# Out:
# hello

# %%
a
# Out:
# 'hello'

# %%
'I'm a student'
# Out:
#   Cell In[44], line 1
#     'I'm a student'
#                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"I'm a student"
# Out:
# "I'm a student"

# %%
'I\'m a student'
# Out:
# "I'm a student"

# %%
"hello"
'hi'
"bye"
'why'
# Out:
# 'why'

# %%
print("hello")
print('hi')
print("bye")
print('why')
# Out:
# hello
# hi
# bye
# why

# %%
'hello', 'hi', 'bye', 'why'
# Out:
# ('hello', 'hi', 'bye', 'why')

# %%
'hello'\n'hi'\n'bye'\n'why'
# Out:
#   Cell In[68], line 1
#     'hello'\n'hi'\n'bye'\n'why'
#             ^
# SyntaxError: unexpected character after line continuation character

# %%
print('hello'\n'hi'\n'bye'\n'why')
# Out:
#   Cell In[69], line 1
#     print('hello'\n'hi'\n'bye'\n'why')
#                   ^
# SyntaxError: unexpected character after line continuation character

# %%
print('hello''\n''hi''\n''bye''\n''why')
# Out:
# hello
# hi
# bye
# why

# %%
print('hello','hi','bye','why')
# Out:
# hello hi bye why

# %%
print('hello',',''hi',',''bye',',''why')
# Out:
# hello ,hi ,bye ,why

# %%
print('hello,''hi,''bye,''why')
# Out:
# hello,hi,bye,why

# %%
'This is one line
but this is another line'
# Out:
#   Cell In[50], line 1
#     'This is one line
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'This is one line'
'but this is another line'
# Out:
# 'but this is another line'

# %%
'This is one line\n'
'but this is another line'
# Out:
# 'but this is another line'

# %%
print('This is one line\n')
'but this is another line'
# Out:
# This is one line
# 'but this is another line'

# %%
print('This is one line')
'but this is another line'
# Out:
# This is one line
# 'but this is another line'

# %%
print(This is one line)
print(but this is another line)
# Out:
#   Cell In[55], line 1
#     print(This is one line)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('This is one line')
print('but this is another line')
# Out:
# This is one line
# but this is another line

# %%
print('This is one line)
print(but this is another line')
# Out:
#   Cell In[57], line 1
#     print('This is one line)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('first line')
      \n
print('third line')
# Out:
#   Cell In[58], line 2
#     \n
#      ^
# SyntaxError: unexpected character after line continuation character

# %%
print('first line')
      '\n'
print('third line')
# Out:
#   Cell In[59], line 2
#     '\n'
#     ^
# IndentationError: unexpected indent

# %%
print('first line')
'\n'
print('third line')
# Out:
# first line
# third line

# %%
print('first line')
\n
print('third line')
# Out:
#   Cell In[61], line 2
#     \n
#      ^
# SyntaxError: unexpected character after line continuation character

# %%
print('first line')
print(\n)
print('third line')
# Out:
#   Cell In[62], line 2
#     print(\n)
#            ^
# SyntaxError: unexpected character after line continuation character

# %%
print('first line')
print('\n')
print('third line')
# Out:
# first line
#
#
# third line

# %%
print('start end')
# Out:
# start end

# %%
print('start\n end')
# Out:
# start
#  end

# %%
print('start\nend')
# Out:
# start
# end

# %%
a = 5
a = a**
# Out:
#   Cell In[74], line 2
#     a = a**
#            ^
# SyntaxError: invalid syntax

# %%
a = 5
a = a**\
# Out:
#   Cell In[75], line 2
#     a = a**\
#             ^
# _IncompleteInputError: incomplete input

# %%
len('hello how are you? what are you doing?')
# Out:
# 38

# %%
a = 'hello how are you? what are you doing?'
len(a)
# Out:
# 38

# %%
a[5]
# Out:
# ' '

# %%
a[6:10]
# Out:
# 'how '

# %%
a[::-1]
# Out:
# '?gniod uoy era tahw ?uoy era woh olleh'

# %%
a[38]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 a[38]
#
# IndexError: string index out of range

# %%
a[37]
# Out:
# '?'

# %%
a[:]
# Out:
# 'hello how are you? what are you doing?'

# %%
a[6:]
# Out:
# 'how are you? what are you doing?'

# %%
a[-6]
# Out:
# 'd'

# %%
a[-6] = 'b'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 a[-6] = 'b'
#
# TypeError: 'str' object does not support item assignment

# %%
a[: -1]
# Out:
# 'hello how are you? what are you doing'

# %%
a[::-2]
# Out:
# '?no o r aw?o r o le'

# %%
a[::2]
# Out:
# 'hlohwaeyu htaeyudig'

# %%
a[::2:-1]
# Out:
#   Cell In[90], line 1
#     a[::2:-1]
#          ^
# SyntaxError: invalid syntax

# %%
a[:::-1]
# Out:
#   Cell In[91], line 1
#     a[:::-1]
#         ^
# SyntaxError: invalid syntax

# %%
s = 'hello wolrd'
s + 'welcome'
print(s)
# Out:
# hello wolrd

# %%
print(s+'wleocme')
# Out:
# hello wolrdwleocme

# %%
print(s + 'welcome')
# Out:
# hello wolrdwelcome

# %%
print(s + ' welcome')
# Out:
# hello wolrd welcome

# %%
s + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 s + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
s
# Out:
# 'hello wolrd'

# %%
s = s + ' wleocme'
print(s)
# Out:
# hello wolrd wleocme

# %%
s
# Out:
# 'hello wolrd wleocme'

# %%
s*10
# Out:
# 'hello wolrd wleocmehello wolrd wleocmehello wolrd wleocmehello wolrd wleocmehello wolrd wleocmehello wolrd wleocmehello wolrd wleocmehello wolrd wleocmehello wolrd wleocmehello wolrd wleocme'

# %%
s = 'hello world'
s[0]
# Out:
# 'h'

# %%
'hello world'[1]
# Out:
# 'e'

# %%
s.capitalize()
# Out:
# 'Hello world'

# %%
s.casefold()
# Out:
# 'hello world'

# %%
g = 'HWKNDGF'
g.casefold()
# Out:
# 'hwkndgf'

# %%
s.center
# Out:
# <function str.center(width, fillchar=' ', /)>

# %%
s.center()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 s.center()
#
# TypeError: center expected at least 1 argument, got 0

# %%
s.count('l')
# Out:
# 3

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s
# Out:
# 'hello world'

# %%
s = s

# %%
s
# Out:
# 'hello world'

# %%
s = s.upper()
s
# Out:
# 'HELLO WORLD'

# %%
s = s.lower()
s
# Out:
# 'hello world'

# %%
s.count('H')
# Out:
# 0

# %%
s.upper(s.count('H'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 s.upper(s.count('H'))
#
# TypeError: str.upper() takes no arguments (1 given)

# %%
s.upper.count('H')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 s.upper.count('H')
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'count'

# %%
s.replace('h', 'O')
s
# Out:
# 'hello world'

# %%
s.replace('h', 'O')
# Out:
# 'Oello world'

# %%
s
# Out:
# 'hello world'

# %%
k='    hello    we   are  there   '
k.strip()
# Out:
# 'hello    we   are  there'

# %%
k.lstrip()
# Out:
# 'hello    we   are  there   '

# %%
k.rstrip()
# Out:
# '    hello    we   are  there'

# %%
k.split()
# Out:
# ['hello', 'we', 'are', 'there']

# %%
k.split('w')
# Out:
# ['    hello    ', 'e   are  there   ']

# %%
player = 'Thomas'
points = 33
'Last night, ' + player + ' scored ' + str(points) + ' points'
# Out:
# 'Last night, Thomas scored 33 points'

# %%
#Better way
player = 'Thomas'
points = 33
f'Last night, {player} socred {points} points.'
# Out:
# 'Last night, Thomas socred 33 points.'
